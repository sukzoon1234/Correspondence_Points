# %%
import matplotlib.pyplot as plt
import math

sift = [537.83,313.37]
surf = [559.24,840.69]
multi_point = [34.24,14.06]
multi_point_star = [38.34,7.15]
zhang_bihome = [8.96,28.64]
BasesHomo = [63.39,690.27]
ours = [8.96,5.8]


# Ours_novelo = [[3.8e+7, 6.0e+7, 20.6e+7], [0.886, 0.892, 0.899]] #좌측이 # of params, 우측이 delta metric
# Ours_velo = [[3.8e+7, 6.0e+7, 20.6e+7], [0.896, 0.898, 0.906]]


# plt.plot(sift[0], sift[1], linewidth=1, color='cornflowerblue', marker='s', label='SIFT')
# plt.text(sift[0][0]+50, sift[1][0],"SIFT")
# plt.plot(surf[0], surf[1], linewidth=1, color='lime', marker='o',label='SURF')
# plt.text(surf[0][0]+50, surf[1][0],"SURF")
plt.plot(multi_point[0], multi_point[1], linewidth=1, color='#7f7f7f', marker='o', label='Multi-point')
plt.text(multi_point[0]+1, multi_point[1],"Multi-point")
plt.plot(multi_point_star[0], multi_point_star[1], linewidth=1, color='#17becf', marker='s',label='Multi-point*')
plt.text(multi_point_star[0]+1, multi_point_star[1],"Multi-point*")
plt.plot(zhang_bihome[0], zhang_bihome[1], linewidth=1, color='#e377c2', marker='o', label='Zhang+biHomE')
plt.text(zhang_bihome[0]+1, zhang_bihome[1],"Zhang+biHomE")
plt.plot(BasesHomo[0], BasesHomo[1], linewidth=1, color='blue', marker='o', label='BasesHomo')
plt.text(BasesHomo[0]-13, BasesHomo[1],"BasesHomo")
plt.plot(ours[0], ours[1], linewidth=1, color='orange', marker='o', label='Ours')
plt.text(ours[0]+1, ours[1],"Ours")

plt.xlabel('Inference time (ms)')
plt.ylabel('Mean Errors (day & night)')
plt.xticks([0,20,40])
plt.yscale("log")

plt.legend(loc="upper left")
plt.grid(True)
# plt.show()
plt.savefig('#ofparam.png', dpi=600)
